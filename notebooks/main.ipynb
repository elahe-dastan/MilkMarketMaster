# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
a = pd.read_csv('./../data/2/4/consumptions.csv')
a
# Out:
#      Unnamed: 0    id  data_series_id  product_id  country_id        date  \
# 0           120   721            2823           4           2  2010-01-01
# 1           121   722            2823           4           2  2010-02-01
# 2           122   723            2823           4           2  2010-03-01
# 3           123   724            2823           4           2  2010-04-01
# 4           124   725            2823           4           2  2010-05-01
# ..          ...   ...             ...         ...         ...         ...
# 296         416  1557            2823           4           2  2009-09-01
# 297         417  1558            2823           4           2  2009-10-01
# 298         418  1559            2823           4           2  2009-11-01
# 299         419  1560            2823           4           2  2009-12-01
# 300         420  3242            2823           4           2  2020-01-01
#
#     data_interval raw_unit     raw_value unit  ...         updated_at.1  \
# ...

# %%
a.unit.unique()
# Out:
# array(['mt'], dtype=object)

# %%
a.describe(include='all')
# Out:
#                  id  data_series_id  product_id  country_id        date  \
# count    421.000000      421.000000  421.000000       421.0         421
# unique          NaN             NaN         NaN         NaN         301
# top             NaN             NaN         NaN         NaN  2010-01-01
# freq            NaN             NaN         NaN         NaN           2
# mean    1183.971496     2822.714964    3.144893         2.0         NaN
# std      306.860732        0.451969    1.355906         0.0         NaN
# min      721.000000     2822.000000    1.000000         2.0         NaN
# 25%      826.000000     2822.000000    1.000000         2.0         NaN
# 50%     1171.000000     2823.000000    4.000000         2.0         NaN
# 75%     1456.000000     2823.000000    4.000000         2.0         NaN
# max     3242.000000     2823.000000    4.000000         2.0         NaN
#
#        data_interval raw_unit     raw_value unit         value  ...  \
# ...

# %%
a_1 = a[a['data_series_id'] == 2823]
a_1.describe(include='all')
# 5044132.466
# 5.044077e+06
# Out:
#                  id  data_series_id  product_id  country_id        date  \
# count    301.000000           301.0       301.0       301.0         301
# unique          NaN             NaN         NaN         NaN         301
# top             NaN             NaN         NaN         NaN  2010-01-01
# freq            NaN             NaN         NaN         NaN           1
# mean    1201.302326          2823.0         4.0         2.0         NaN
# std      360.959386             0.0         0.0         0.0         NaN
# min      721.000000          2823.0         4.0         2.0         NaN
# 25%      796.000000          2823.0         4.0         2.0         NaN
# 50%     1411.000000          2823.0         4.0         2.0         NaN
# 75%     1486.000000          2823.0         4.0         2.0         NaN
# max     3242.000000          2823.0         4.0         2.0         NaN
#
#        data_interval raw_unit     raw_value unit         value  ...  \
# ...

# %%
a_2 = a[a['data_series_id'] == 2822]
a_2.describe(include='all')
# Out:
#                  id  data_series_id  product_id  country_id        date  \
# count    120.000000           120.0       120.0       120.0         120
# unique          NaN             NaN         NaN         NaN         120
# top             NaN             NaN         NaN         NaN  2010-01-01
# freq            NaN             NaN         NaN         NaN           1
# mean    1140.500000          2822.0         1.0         2.0         NaN
# std       34.785054             0.0         0.0         0.0         NaN
# min     1081.000000          2822.0         1.0         2.0         NaN
# 25%     1110.750000          2822.0         1.0         2.0         NaN
# 50%     1140.500000          2822.0         1.0         2.0         NaN
# 75%     1170.250000          2822.0         1.0         2.0         NaN
# max     1200.000000          2822.0         1.0         2.0         NaN
#
#        data_interval raw_unit     raw_value unit         value  ...  \
# ...

# %%
plt.plot(a_1['date'], a_1['raw_value'])
plt.plot(a_1['date'], a_1['value'] * 2000)

# %%
a_1.date.max()
# Out:
# '2020-01-01'

# %%
print(a.date.min())
print(a.date.max())
print()
print(b.date.min())
print(b.date.max())
print()
print(c.date.min())
print(c.date.max())
print()
print(d.date.min())
print(d.date.max())
print()
print(e.date.min())
print(e.date.max())
print()
print(f.date.min())
print(f.date.max())
# Out:
# 1995-01-01
# 2020-01-01
#
# 1961-01-01
# 2025-10-01
#
# 1930-01-01
# 2023-12-04
#
# 1991-05-06
# 2023-12-21
#
# 2000-01-01
# 2023-09-01
#
# 1988-01-01
# 2023-11-01

# %%
plt.plot(a_1['date'], a_1['value'])

# %%
plt.plot(a_1['date'], a_1['raw_value'] - a_1['value'])

# %%
b = pd.read_csv('./data/inflation_rates.csv')
b
# Out:
#        id  data_series_id  country_id        date data_interval      rate  \
# 0     818       1476439.0           2  1961-01-01        yearly  1.070362
# 1     819       1476439.0           2  1962-01-01        yearly  1.176077
# 2     820       1476439.0           2  1963-01-01        yearly  1.256060
# 3     821       1476439.0           2  1964-01-01        yearly  1.322089
# 4     822       1476439.0           2  1965-01-01        yearly  1.578693
# ..    ...             ...         ...         ...           ...       ...
# 955  8666       1476433.0         131  2025-01-01        yearly  2.521823
# 956  8810       1476497.0         131  2025-01-01     quarterly  2.829543
# 957  8811       1476497.0         131  2025-04-01     quarterly  2.625408
# 958  8812       1476497.0         131  2025-07-01     quarterly  2.421585
# 959  8813       1476497.0         131  2025-10-01     quarterly  2.218166
#
#               created_at           updated_at  id.1           name code  \
# ...

# %%
b.data_interval.unique()
# Out:
# array(['yearly', 'quarterly'], dtype=object)

# %%
b.describe(include='all')
# Out:
#                  id  data_series_id  country_id        date data_interval  \
# count    960.000000    9.550000e+02  960.000000         960           960
# unique          NaN             NaN         NaN         260             2
# top             NaN             NaN         NaN  2008-01-01     quarterly
# freq            NaN             NaN         NaN           8           768
# mean    4627.737500    1.476482e+06   76.963542         NaN           NaN
# std     2529.647159    2.234939e+01   57.947908         NaN           NaN
# min      470.000000    1.476433e+06    2.000000         NaN           NaN
# 25%     2509.750000    1.476474e+06    2.000000         NaN           NaN
# 50%     6073.500000    1.476497e+06  129.000000         NaN           NaN
# 75%     7209.250000    1.476502e+06  131.000000         NaN           NaN
# max     8833.000000    1.476502e+06  131.000000         NaN           NaN
#
#               rate           created_at           updated_at        id.1  \
# ...

# %%
b_1 = b[b['data_series_id'] == 1476439]
b_1.describe(include='all')
# Out:
#                  id  data_series_id  country_id        date data_interval  \
# count     65.000000            65.0        65.0          65            65
# unique          NaN             NaN         NaN          65             1
# top             NaN             NaN         NaN  1961-01-01        yearly
# freq            NaN             NaN         NaN           1            65
# mean     969.846154       1476439.0         2.0         NaN           NaN
# std      970.437550             0.0         0.0         NaN           NaN
# min      818.000000       1476439.0         2.0         NaN           NaN
# 25%      834.000000       1476439.0         2.0         NaN           NaN
# 50%      850.000000       1476439.0         2.0         NaN           NaN
# 75%      866.000000       1476439.0         2.0         NaN           NaN
# max     8672.000000       1476439.0         2.0         NaN           NaN
#
#              rate           created_at           updated_at  id.1  \
# ...

# %%
b_2 = b[b['data_series_id'] == 1476502]
b_2.describe(include='all')
# Out:
#                  id  data_series_id  country_id        date data_interval  \
# count    260.000000           260.0       260.0         260           260
# unique          NaN             NaN         NaN         260             1
# top             NaN             NaN         NaN  1961-01-01     quarterly
# freq            NaN             NaN         NaN           1           260
# mean    7325.038462       1476502.0         2.0         NaN           NaN
# std      202.471502             0.0         0.0         NaN           NaN
# min     7174.000000       1476502.0         2.0         NaN           NaN
# 25%     7238.750000       1476502.0         2.0         NaN           NaN
# 50%     7303.500000       1476502.0         2.0         NaN           NaN
# 75%     7368.250000       1476502.0         2.0         NaN           NaN
# max     8833.000000       1476502.0         2.0         NaN           NaN
#
#               rate           created_at           updated_at   id.1  \
# ...

# %%
plt.plot(b_1['date'], b_1['rate'])

# %%
c = pd.read_csv('./../data/2/4/production.csv')
c
# Out:
#      Unnamed: 0      id  data_series_id  product_id  country_id        date  \
# 0             0       4            1583           4           2  2019-01-01
# 1             1       9            1583           4           2  2019-02-01
# 2             2      14            1583           4           2  2019-03-01
# 3             3      19            1583           4           2  2019-04-01
# 4             4      24            1583           4           2  2019-05-01
# ..          ...     ...             ...         ...         ...         ...
# 221        3013  205233            1583           4           2  2023-06-01
# 222        3024  210573            1583           4           2  2023-07-01
# 223        3036  211656            1583           4           2  2023-08-01
# 224        3048  216789            1583           4           2  2023-09-01
# 225        3061  217408            1583           4           2  2023-10-01
#
# ...

# %%
c.describe(include='all')
# Out:
#          Unnamed: 0             id  data_series_id  product_id  country_id  \
# count    226.000000     226.000000           226.0       226.0       226.0
# unique          NaN            NaN             NaN         NaN         NaN
# top             NaN            NaN             NaN         NaN         NaN
# freq            NaN            NaN             NaN         NaN         NaN
# mean     641.128319   34431.044248          1583.0         4.0         2.0
# std     1063.235129   68937.347271             0.0         0.0         0.0
# min        0.000000       4.000000          1583.0         4.0         2.0
# 25%       56.250000     285.250000          1583.0         4.0         2.0
# 50%      112.500000     566.500000          1583.0         4.0         2.0
# 75%      168.750000     847.750000          1583.0         4.0         2.0
# max     3061.000000  217408.000000          1583.0         4.0         2.0
#
#               date data_interval raw_unit     raw_value unit  ...  \
# ...

# %%
c_1 = c[(c['country_id'] == 2)]
c_1.describe(include='all')
# Out:
#          Unnamed: 0             id  data_series_id  product_id  country_id  \
# count    226.000000     226.000000           226.0       226.0       226.0
# unique          NaN            NaN             NaN         NaN         NaN
# top             NaN            NaN             NaN         NaN         NaN
# freq            NaN            NaN             NaN         NaN         NaN
# mean     641.128319   34431.044248          1583.0         4.0         2.0
# std     1063.235129   68937.347271             0.0         0.0         0.0
# min        0.000000       4.000000          1583.0         4.0         2.0
# 25%       56.250000     285.250000          1583.0         4.0         2.0
# 50%      112.500000     566.500000          1583.0         4.0         2.0
# 75%      168.750000     847.750000          1583.0         4.0         2.0
# max     3061.000000  217408.000000          1583.0         4.0         2.0
#
#               date data_interval raw_unit     raw_value unit  ...  \
# ...

# %%
c = c.sort_values(by='date')
plt.plot(c['date'], c['value'])

# %%
c.date.max()
# Out:
# '2023-10-01'

# %%
a = a.sort_values(by='date')
plt.plot(a['date'], a['value'])

# %%
plt.plot(d['date'], d['price'])

# %%
plt.plot(c_1['date'], c_1['raw_value'])

# %%
d = pd.read_csv('./../data/2/4/smp_quotations.csv')
d = d.sort_values(by='date')

# %%
d[d['date'] == '2001-04-23']
# Out:
#          id  data_series_id  product_id  data_source_id        date  \
# 0     85115             652           4              30  2001-04-23
# 894   86795             792           4              19  2001-04-23
# 1801  87702             886           4               1  2001-04-23
#
#      data_interval raw_currency raw_unit  raw_price currency  ...  \
# 0           weekly          EUR       mt    2291.59      EUR  ...
# 894         weekly          EUR       mt    2213.89      EUR  ...
# 1801        weekly          EUR       mt    2377.30      EUR  ...
#
#              created_at.1         updated_at.1 id.2 product_group_id  \
# 0     2021-06-21 16:01:39  2021-06-21 16:01:39    4                2
# 894   2021-06-21 16:01:39  2021-06-21 16:01:39    4                2
# 1801  2021-06-21 16:01:39  2021-06-21 16:01:39    4                2
#
#           name.1                      slug         created_at.2  \
# 0     SMP (Food)  skimmed-milk-powder-food  2019-02-02 15:06:27
# ...

# %%
d.describe(include='all')
# Out:
#                   id  data_series_id  product_id  data_source_id        date  \
# count   8.238000e+03     8238.000000      8238.0     8238.000000        8238
# unique           NaN             NaN         NaN             NaN        4764
# top              NaN             NaN         NaN             NaN  2018-05-07
# freq             NaN             NaN         NaN             NaN           5
# mean    2.430487e+05      860.464433         4.0       58.769240         NaN
# std     1.563701e+05      110.841049         0.0       45.889306         NaN
# min     8.511500e+04      646.000000         4.0        1.000000         NaN
# 25%     8.796025e+04      792.000000         4.0       19.000000         NaN
# 50%     2.430675e+05      912.000000         4.0       43.000000         NaN
# 75%     4.317648e+05      961.000000         4.0       71.000000         NaN
# max     1.668383e+06      996.000000         4.0      133.000000         NaN
#
# ...

# %%
d.country_id.unique()
# Out:
# array([129,  67,   1, 131,   2])

# %%
d[d['country_id']==2]
# Out:
#            id  data_series_id  product_id  data_source_id        date  \
# 6168   428512             961           4             133  2020-10-01
# 6169   431756             961           4             133  2000-01-06
# 6170   431757             961           4             133  2000-01-13
# 6171   431758             961           4             133  2000-01-20
# 6172   431759             961           4             133  2000-01-27
# ...       ...             ...         ...             ...         ...
# 8194   572903             961           4             133  2023-11-21
# 8207   634080             961           4             133  2023-11-30
# 8217   897568             961           4             133  2023-12-07
# 8226  1651445             961           4             133  2023-12-14
# 8236  1663349             961           4             133  2023-12-21
#
#      data_interval raw_currency raw_unit  raw_price currency  ...  \
# ...

# %%
d_1 = d[d['data_series_id'] == 961]
d_1.describe(include='all')
# Out:
#                   id  data_series_id  product_id  data_source_id        date  \
# count   1.802000e+03          1802.0      1802.0          1802.0        1802
# unique           NaN             NaN         NaN             NaN        1802
# top              NaN             NaN         NaN             NaN  2020-10-01
# freq             NaN             NaN         NaN             NaN           1
# mean    4.366896e+05           961.0         4.0           133.0         NaN
# std     4.296700e+04             0.0         0.0             0.0         NaN
# min     4.285120e+05           961.0         4.0           133.0         NaN
# 25%     4.322052e+05           961.0         4.0           133.0         NaN
# 50%     4.326555e+05           961.0         4.0           133.0         NaN
# 75%     4.370578e+05           961.0         4.0           133.0         NaN
# max     1.663349e+06           961.0         4.0           133.0         NaN
#
# ...

# %%
plt.plot(d_1['date'], d_1['raw_price'])

# %%
plt.plot(d_1['date'], d_1['price'])

# %%
e = pd.read_csv('./data/stocks.csv')
e
# Out:
#         id  data_series_id  product_id  country_id        date data_interval  \
# 0        6             629           4         199  2011-12-01       monthly
# 1     2740             629           4         199  2000-01-01       monthly
# 2     2746             629           4         199  2000-01-01       monthly
# 3     2752             629           4         199  2000-02-01       monthly
# 4     2758             629           4         199  2000-03-01       monthly
# ..     ...             ...         ...         ...         ...           ...
# 800  36220             629           4         199  2023-05-01       monthly
# 801  36318             629           4         199  2023-06-01       monthly
# 802  36586             629           4         199  2023-07-01       monthly
# 803  36587             629           4         199  2023-08-01       monthly
# 804  36644             629           4         199  2023-09-01       monthly
#
# ...

# %%
e[e['country_id']==2]
# Out:
#         id  data_series_id  product_id  country_id        date data_interval  \
# 518   9912             496           4           2  2020-02-01       monthly
# 519   9913             496           4           2  2020-03-01       monthly
# 520   9914             496           4           2  2020-04-01       monthly
# 521   9915             496           4           2  2020-05-01       monthly
# 522   9916             496           4           2  2020-06-01       monthly
# ..     ...             ...         ...         ...         ...           ...
# 764  10158             496           4           2  2000-10-01       monthly
# 765  10159             496           4           2  2000-11-01       monthly
# 766  10160             496           4           2  2000-12-01       monthly
# 767  10161             496           4           2  2001-01-01       monthly
# 768  10167             496           4           2  2020-12-01       monthly
#
# ...

# %%
e.describe(include='all')
# Out:
#                   id  data_series_id  product_id  country_id        date  \
# count     805.000000      805.000000       805.0  805.000000         805
# unique           NaN             NaN         NaN         NaN         285
# top              NaN             NaN         NaN         NaN  2015-05-01
# freq             NaN             NaN         NaN         NaN           6
# mean     7269.616149      587.530435         4.0  137.575155         NaN
# std      6050.306511       61.647777         0.0   91.312872         NaN
# min         6.000000      496.000000         4.0    2.000000         NaN
# 25%      3934.000000      496.000000         4.0    2.000000         NaN
# 50%      5028.000000      629.000000         4.0  199.000000         NaN
# 75%      9997.000000      629.000000         4.0  199.000000         NaN
# max     36644.000000      629.000000         4.0  199.000000         NaN
#
#        data_interval raw_unit     raw_value unit          value  ...  \
# ...

# %%
e_1 = e[e['data_series_id'] == 496]
e_1.describe(include='all')
# Out:
#                   id  data_series_id  product_id  country_id        date  \
# count     251.000000           251.0       251.0       251.0         251
# unique           NaN             NaN         NaN         NaN         251
# top              NaN             NaN         NaN         NaN  2020-02-01
# freq             NaN             NaN         NaN         NaN           1
# mean    10037.019920           496.0         4.0         2.0         NaN
# std        72.636765             0.0         0.0         0.0         NaN
# min      9912.000000           496.0         4.0         2.0         NaN
# 25%      9974.500000           496.0         4.0         2.0         NaN
# 50%     10037.000000           496.0         4.0         2.0         NaN
# 75%     10099.500000           496.0         4.0         2.0         NaN
# max     10167.000000           496.0         4.0         2.0         NaN
#
#        data_interval raw_unit     raw_value unit         value  ...  \
# ...

# %%
e_1_1 = e_1[e_1['type'] == 'commercial']
plt.plot(e_1_1['date'], e_1_1['raw_value'])

# %%
f = pd.read_csv('./data/total_import_export.csv')
f
# Out:
#            id  data_series_id  country_id  hs_code  type data_interval  \
# 0       20177          144362           1    40210     2       monthly
# 1     4995657          241084           1    40210     1       monthly
# 2      545713          144379           2    40210     2       monthly
# 3      545714          144378           2    40210     1       monthly
# 4      545715          144379           2    40210     2       monthly
# ...       ...             ...         ...      ...   ...           ...
# 4788  8201841          185292         200    40210     2       monthly
# 4789  8342710          185291         200    40210     1       monthly
# 4790  8342815          185292         200    40210     2       monthly
# 4791  8504503          185291         200    40210     1       monthly
# 4792  8504618          185292         200    40210     2       monthly
#
#             date unit    amount         price           created_at  \
# ...

# %%
f.describe(include='all')
# Out:
#                   id  data_series_id   country_id  hs_code         type  \
# count   4.793000e+03     4793.000000  4793.000000   4793.0  4793.000000
# unique           NaN             NaN          NaN      NaN          NaN
# top              NaN             NaN          NaN      NaN          NaN
# freq             NaN             NaN          NaN      NaN          NaN
# mean    9.644977e+05   169089.008346   121.331734  40210.0     1.501148
# std     1.835177e+06    14942.205437    72.300749      0.0     0.500051
# min     2.017700e+04   144362.000000     1.000000  40210.0     1.000000
# 25%     1.812350e+05   157772.000000    67.000000  40210.0     1.000000
# 50%     1.903880e+05   170896.000000   129.000000  40210.0     2.000000
# 75%     5.461250e+05   184854.000000   199.000000  40210.0     2.000000
# max     8.573072e+06   241084.000000   200.000000  40210.0     2.000000
#
#        data_interval        date  unit        amount         price  \
# ...

# %%
f_1 = f[f['data_series_id'] == 144378]
f_1.describe(include='all')
# Out:
#                   id  data_series_id  country_id  hs_code   type  \
# count   4.180000e+02           418.0       418.0    418.0  418.0
# unique           NaN             NaN         NaN      NaN    NaN
# top              NaN             NaN         NaN      NaN    NaN
# freq             NaN             NaN         NaN      NaN    NaN
# mean    8.250256e+05        144378.0         2.0  40210.0    1.0
# std     1.074065e+06             0.0         0.0      0.0    0.0
# min     5.457140e+05        144378.0         2.0  40210.0    1.0
# 25%     5.459235e+05        144378.0         2.0  40210.0    1.0
# 50%     5.461340e+05        144378.0         2.0  40210.0    1.0
# 75%     5.463545e+05        144378.0         2.0  40210.0    1.0
# max     8.498903e+06        144378.0         2.0  40210.0    1.0
#
#        data_interval        date unit       amount         price  \
# count            418         418  418   418.000000  4.180000e+02
# ...

# %%
plt.plot(f_1['date'], f_1['amount'])

# %%
plt.plot(f_1['date'], f_1['price'])

# %%
plt.plot(a_1['date'], a_1['value'], label='consumption')
plt.plot(b_1['date'], b_1['rate'] * 10000, label='inflation')
plt.plot(c_1['date'], c_1['raw_value'])
# plt.plot(d_1['date'], d_1['price'])
# plt.plot(e_1_1['date'], e_1_1['raw_value'])
# plt.plot(f_1['date'], f_1['price'])
# plt.legend()

# %%
b_1.data_interval
# Out:
# 0      yearly
# 1      yearly
# 2      yearly
# 3      yearly
# 4      yearly
#         ...
# 60     yearly
# 61     yearly
# 62     yearly
# 63     yearly
# 320    yearly
# Name: data_interval, Length: 65, dtype: object

# %%
a_1.data_interval
# Out:
# 120    monthly
# 121    monthly
# 122    monthly
# 123    monthly
# 124    monthly
#         ...
# 416    monthly
# 417    monthly
# 418    monthly
# 419    monthly
# 420    monthly
# Name: data_interval, Length: 301, dtype: object

# %%
len(a_1)
# Out:
# 301

# %%
len(b_1)
# Out:
# 65

# %%
x = (((a_1.merge(b_1, on='date', how='outer').
     merge(c_1, on='date', how='outer').
     merge(d_1, on='date', how='outer', suffixes=("_a", "_b"))).
     merge(e_1_1, on='date', how='outer', suffixes=("_1", "_2"))).
     merge(f_1, on='date', how='outer', suffixes=("_n", "_m")))
x
# Out:
#        id_x  data_series_id_x  product_id_x  country_id_x        date  \
# 0     721.0            2823.0           4.0           2.0  2010-01-01
# 1     722.0            2823.0           4.0           2.0  2010-02-01
# 2     723.0            2823.0           4.0           2.0  2010-03-01
# 3     724.0            2823.0           4.0           2.0  2010-04-01
# 4     725.0            2823.0           4.0           2.0  2010-05-01
# ...     ...               ...           ...           ...         ...
# 2189    NaN               NaN           NaN           NaN  1994-07-01
# 2190    NaN               NaN           NaN           NaN  1994-08-01
# 2191    NaN               NaN           NaN           NaN  1994-10-01
# 2192    NaN               NaN           NaN           NaN  1994-11-01
# 2193    NaN               NaN           NaN           NaN  1991-04-01
#
#      data_interval_x raw_unit_x   raw_value_x unit_x   value_x  ...  \
# ...

# %%
# plt.plot(x['date'], x['value_x'], label='consumption')
# plt.plot(x['date'], x['rate']*2000, label='inflation')
# plt.plot(x['date'], x['value_y'], label='production')
# plt.plot(x['date'], x['price_n'] * 10, label='smp')
# plt.plot(x['date'], x['value'], label='stock')
# plt.plot(x['date'], x['amount'], label='import_export_amount')
plt.plot(x['date'], x['price_m']/100, label='import_export_price')

plt.legend()

# %%
y = (((a_1.merge(b_1, on='date', how='inner').
     # merge(c_1, on='date', how='inner').
     merge(d_1, on='date', how='inner', suffixes=("_a", "_b")))))
     # merge(e_1_1, on='date', how='inner', suffixes=("_1", "_2"))).
     # merge(f_1, on='date', how='inner', suffixes=("_n", "_m")))
y
# Out:
#    id_x  data_series_id_x  product_id_a  country_id_x        date  \
# 0  1489              2823             4             2  2004-01-01
#
#   data_interval_x raw_unit_a    raw_value unit_a     value  ...  \
# 0         monthly         lb  61829419.62     mt  28045.64  ...
#
#           created_at.1         updated_at.1  id.2_b product_group_id_b  \
# 0  2023-05-16 12:37:44  2023-05-16 12:37:44       4                  2
#
#      name.1_b                    slug_b       created_at.2_b  \
# 0  SMP (Food)  skimmed-milk-powder-food  2019-02-02 15:06:27
#
#         updated_at.2_b deleted_at  type_b
# 0  2021-02-15 07:54:23        NaN   solid
#
# [1 rows x 70 columns]

# %%
d
# Out:
#            id  data_series_id  product_id  data_source_id        date  \
# 0       85115             652           4              30  2001-04-23
# 1       85116             652           4              30  2001-04-30
# 2       85117             652           4              30  2001-05-07
# 3       85118             652           4              30  2001-05-14
# 4       85119             652           4              30  2001-05-21
# ...       ...             ...         ...             ...         ...
# 8233  1652235             652           4              30  2023-12-20
# 8234  1652369             886           4               1  2023-12-17
# 8235  1652383             912           4              71  2023-12-20
# 8236  1663349             961           4             133  2023-12-21
# 8237  1668383             912           4              71  2023-12-21
#
#      data_interval raw_currency raw_unit  raw_price currency  ...  \
# ...

# %%
z = d['price'] / b['rate']
z
# Out:
# 0       2140.948576
# 1       1975.508406
# 2       1878.620448
# 3       1836.275773
# 4       1572.300631
#            ...
# 8233            NaN
# 8234            NaN
# 8235            NaN
# 8236            NaN
# 8237            NaN
# Length: 8238, dtype: float64

# %%
len(d)
# Out:
# 8238

# %%
len(b)
# Out:
# 960

# %%
z = d.merge(b, on='date', how='inner').merge(a, on='date', suffixes=("x", "y"), how='inner')
z
# Out:
#        id_x  data_series_id_x  product_idx  data_source_id        date  \
# 0     85158               652            4              30  2002-04-01
# 1     85158               652            4              30  2002-04-01
# 2     85158               652            4              30  2002-04-01
# 3     85158               652            4              30  2002-04-01
# 4     86840               792            4              19  2002-04-01
# ..      ...               ...          ...             ...         ...
# 463  436953               961            4             133  1999-04-01
# 464  436992               961            4             133  1998-07-01
# 465  436992               961            4             133  1998-07-01
# 466  436992               961            4             133  1998-07-01
# 467  436992               961            4             133  1998-07-01
#
#     data_interval_x raw_currency raw_unitx  raw_price currency  ...  \
# ...

# %%
plt.plot(z['date'], z['price'], label='price')
plt.plot(z['date'], z['price']/z['rate'], label='adjusted_price')
plt.plot(z['date'], z['value']/100, label='consumption')
plt.legend()

# %%
b[b['data_series_id'] == 1476439.0]
# Out:
#        id  data_series_id  country_id        date data_interval      rate  \
# 0     818       1476439.0           2  1961-01-01        yearly  1.070362
# 1     819       1476439.0           2  1962-01-01        yearly  1.176077
# 2     820       1476439.0           2  1963-01-01        yearly  1.256060
# 3     821       1476439.0           2  1964-01-01        yearly  1.322089
# 4     822       1476439.0           2  1965-01-01        yearly  1.578693
# ..    ...             ...         ...         ...           ...       ...
# 60    878       1476439.0           2  2021-01-01        yearly  4.682560
# 61    879       1476439.0           2  2022-01-01        yearly  7.986482
# 62    880       1476439.0           2  2023-01-01        yearly  4.172716
# 63    881       1476439.0           2  2024-01-01        yearly  2.826745
# 320  8672       1476439.0           2  2025-01-01        yearly  2.165225
#
#               created_at           updated_at  id.1           name code  \
# ...

# %%
b[b['data_series_id'] == 1476502.0]
# Out:
#        id  data_series_id  country_id        date data_interval      rate  \
# 64   7174       1476502.0           2  1961-01-01     quarterly  1.508107
# 65   7175       1476502.0           2  1961-04-01     quarterly  0.867899
# 66   7176       1476502.0           2  1961-07-01     quarterly  1.205362
# 67   7177       1476502.0           2  1961-10-01     quarterly  0.705171
# 68   7178       1476502.0           2  1962-01-01     quarterly  0.893655
# ..    ...             ...         ...         ...           ...       ...
# 319  7429       1476502.0           2  2024-10-01     quarterly  2.426777
# 321  8830       1476502.0           2  2025-01-01     quarterly  2.270611
# 322  8831       1476502.0           2  2025-04-01     quarterly  2.186447
# 323  8832       1476502.0           2  2025-07-01     quarterly  2.129991
# 324  8833       1476502.0           2  2025-10-01     quarterly  2.075664
#
#               created_at           updated_at  id.1           name code  \
# ...
